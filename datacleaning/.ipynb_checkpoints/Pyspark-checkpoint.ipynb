# %%
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName("PySpark App") \
    .config("spark.jars", "/project/postgresql-42.3.4.jar") \
    .getOrCreate()

# %%
postgres_uri = "jdbc:postgresql://de166.c0imhubqi7yg.us-east-1.rds.amazonaws.com:5432/Initialdatabase"
dbtable= "public.merged"
user = "user"
password = "password"

# %%
df = spark.read \
    .format("jdbc") \
    .option("url", postgres_uri) \
    .option("user", user) \
    .option("password", password) \
    .option("driver", "org.postgresql.Driver") \
    .option("query","select * from merged")\
    .load()

# %%
df
# Out:
#        Region/Country Second Tier Authority      Local Authority       Code  \
# 0          North East            Darlington           Darlington  E06000005
# 1          North East                Durham        County Durham  E06000047
# 2          North East                Durham        County Durham  E06000047
# 3          North East             Gateshead            Gateshead  E08000037
# 4          North East             Gateshead            Gateshead  E08000037
# ..                ...                   ...                  ...        ...
# 619  Northern Ireland      Northern Ireland  Mid and East Antrim  N09000008
# 620  Northern Ireland      Northern Ireland  Mid and East Antrim  N09000008
# 621  Northern Ireland      Northern Ireland           Mid Ulster  N09000009
# 622  Northern Ireland      Northern Ireland           Mid Ulster  N09000009
# 623  Northern Ireland      Northern Ireland           Mid Ulster  N09000009
#
# ...

# %%
df_merge1
