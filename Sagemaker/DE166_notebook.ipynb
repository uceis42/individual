# %%
import boto3, re, sys, math, json, os, sagemaker, urllib.request
from sagemaker import get_execution_role
import numpy as np                                
import pandas as pd                               
import matplotlib.pyplot as plt                   
from IPython.display import Image                 
from IPython.display import display               
from time import gmtime, strftime                 
from sagemaker.predictor import csv_serializer   
# import needed packages 
# Define IAM role
role = get_execution_role()
prefix = 'sagemaker/DEMO-xgboost-dm'
containers = {'us-west-2': '433757028032.dkr.ecr.us-west-2.amazonaws.com/xgboost:latest',
              'us-east-1': '811284229777.dkr.ecr.us-east-1.amazonaws.com/xgboost:latest',
              'us-east-2': '825641698319.dkr.ecr.us-east-2.amazonaws.com/xgboost:latest',
              'eu-west-1': '685385470294.dkr.ecr.eu-west-1.amazonaws.com/xgboost:latest'} # create XGBoost container for differnt region
my_region = boto3.session.Session().region_name # set the region of the instance
print("Success - the MySageMakerInstance is in the " + my_region + " region. You will use the " + containers[my_region] + " container for your SageMaker endpoint.")
# Out:
# Success - the MySageMakerInstance is in the us-west-2 region. You will use the 433757028032.dkr.ecr.us-west-2.amazonaws.com/xgboost:latest container for your SageMaker endpoint.

# %%
bucket_name = 'de166-sagemaker-shihao' # set up the name 
s3 = boto3.resource('s3')
try:# try to get the right reigon and create bucket
    if  my_region == 'us-east-1': 
        s3.create_bucket(Bucket=bucket_name)
    else: 
        s3.create_bucket(Bucket=bucket_name, CreateBucketConfiguration={ 'LocationConstraint': my_region })
    print('S3 bucket created successfully')
except Exception as e:
    print('S3 error: ',e)
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/boto3/compat.py:88: PythonDeprecationWarning: Boto3 will no longer support Python 3.6 starting May 30, 2022. To continue receiving service updates, bug fixes, and security updates please upgrade to Python 3.7 or later. More information can be found here: https://aws.amazon.com/blogs/developer/python-support-policy-updates-for-aws-sdks-and-tools/
#   warnings.warn(warning, PythonDeprecationWarning)
# S3 error:  An error occurred (BucketAlreadyOwnedByYou) when calling the CreateBucket operation: Your previous request to create the named bucket succeeded and you already own it.

# %%
import pyarrow.parquet as pq
import s3fs
# read the need file to pd
s3 = s3fs.S3FileSystem()
model_data = pq.read_table('s3://de166-sagemaker-shihao/merged.parquet', filesystem=s3).to_pandas()

# %%
# drop all the unneeded data before we train the model
model_data= model_data.drop(columns = ['Local Authority Distract Name','Region/Country','Second Tier Authority','Code','Year','Operator','Site','Postcode','Reference','Substance Name','Local Authority'])

# %%
model_data
# Out:
#      Industry Electricity  Industry Gas   Industry 'Other Fuels'  \
# 0               17.786253      64.760412               23.930058
# 1              110.906985      86.680235              130.746196
# 2              110.906985      86.680235              130.746196
# 3               45.752494      76.066494               35.248639
# 4               45.752494      76.066494               35.248639
# ..                    ...            ...                     ...
# 619             38.559634      56.107100              217.406073
# 620             38.559634      56.107100              217.406073
# 621             75.808282      24.178805              349.697965
# 622             75.808282      24.178805              349.697965
# 623             75.808282      24.178805              349.697965
#
#      Large Industrial Installations  Agriculture  Industry Total    2019 year  \
# 0                          0.050426     5.952103      112.479252    49.343000
# 1                         10.899522    45.994055      385.226992     0.043075
# 2                         10.899522    45.994055      385.226992     4.700560
# 3                          4.795098     1.542726      163.405451    22.400000
# 4                          4.795098     1.542726      163.405451    22.200000
# ..                              ...          ...             ...          ...
# 619                       11.847051    45.652023      369.571881  1010.033350
# 620                       11.847051    45.652023      369.571881  1141.294000
# 621                      357.242559    92.253520      899.181131    18.977000
# 622                      357.242559    92.253520      899.181131   313.326000
# 623                      357.242559    92.253520      899.181131    25.460000
#
#      label
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ..     ...
# 619     -1
# 620     -1
# 621      1
# 622     -1
# 623      1
#
# [624 rows x 8 columns]

# %%
# the lable only take 1,0 so we need to replace -1
model_data['label'] = model_data['label'].replace(-1,0)

# %%
model_data=model_data.astype('float')

# %%
# split data into train and test group
train_data, test_data = np.split(model_data.sample(frac=1, random_state=50), [int(0.7 * len(model_data))])
print(train_data.shape, test_data.shape)
# Out:
# (436, 8) (188, 8)

# %%
#set up train input here
pd.concat([train_data['label'], train_data.drop(['label'], axis=1)], axis=1).to_csv('train.csv', index=False, header=False) # header is not needed and label has to be the first column
boto3.Session().resource('s3').Bucket(bucket_name).Object(os.path.join(prefix, 'train/train.csv')).upload_file('train.csv')
s3_input_train = sagemaker.inputs.TrainingInput(s3_data='s3://{}/{}/train'.format(bucket_name, prefix), content_type='csv')

# %%
# set up the sagemaker session then setting parameters for our XGBoost model
sess = sagemaker.Session()
xgb = sagemaker.estimator.Estimator(containers[my_region],role, instance_count=1, instance_type='ml.m4.xlarge',output_path='s3://{}/{}/output'.format(bucket_name, prefix),sagemaker_session=sess)
xgb.set_hyperparameters(max_depth=5,eta=0.2,gamma=4,min_child_weight=6,subsample=0.8,silent=0,objective='binary:logistic',num_round=100)

# %%
# to fit the model by our data
xgb.fit({'train': s3_input_train})
# Out:
# 2022-04-23 14:05:14 Starting - Starting the training job...
# 2022-04-23 14:05:41 Starting - Preparing the instances for trainingProfilerReport-1650722714: InProgress
# .........
# 2022-04-23 14:07:04 Downloading - Downloading input data......
# 2022-04-23 14:07:59 Training - Downloading the training image...
# 2022-04-23 14:08:45 Training - Training image download completed. Training in progress..Arguments: train
# [2022-04-23:14:08:49:INFO] Running standalone xgboost training.
# [2022-04-23:14:08:49:INFO] Path /opt/ml/input/data/validation does not exist!
# [2022-04-23:14:08:49:INFO] File size need to be processed in the node: 0.05mb. Available memory size in the node: 8492.56mb
# [2022-04-23:14:08:49:INFO] Determined delimiter of CSV input is ','
# [14:08:49] S3DistributionType set as FullyReplicated
# [14:08:49] 436x7 matrix with 3052 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=2
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=3
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 4 pruned nodes, max_depth=2
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 4 pruned nodes, max_depth=2
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=3
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 2 pruned nodes, max_depth=2
# [0]#011train-error:0.087156
# [1]#011train-error:0.084862
# [2]#011train-error:0.057339
# [3]#011train-error:0.045872
# [4]#011train-error:0.066514
# [5]#011train-error:0.052752
# [6]#011train-error:0.041284
# [7]#011train-error:0.038991
# [8]#011train-error:0.036697
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 2 pruned nodes, max_depth=3
# [9]#011train-error:0.03211
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [10]#011train-error:0.03211
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [11]#011train-error:0.03211
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [12]#011train-error:0.029817
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [13]#011train-error:0.03211
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 0 pruned nodes, max_depth=2
# [14]#011train-error:0.029817
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 2 pruned nodes, max_depth=2
# [15]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [16]#011train-error:0.029817
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [17]#011train-error:0.029817
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [18]#011train-error:0.029817
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [19]#011train-error:0.029817
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [20]#011train-error:0.029817
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [21]#011train-error:0.029817
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [22]#011train-error:0.025229
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [23]#011train-error:0.025229
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 2 pruned nodes, max_depth=1
# [24]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [25]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [26]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [27]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [28]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [29]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [30]#011train-error:0.027523
# [31]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [32]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [33]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [34]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [35]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [36]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [37]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [38]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [39]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [40]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [41]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [42]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [43]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [44]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [45]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [46]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [47]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [48]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [49]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [50]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [51]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [52]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [53]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [54]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [55]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [56]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [57]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [58]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [59]#011train-error:0.029817
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [60]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [61]#011train-error:0.029817
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [62]#011train-error:0.029817
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 0 pruned nodes, max_depth=2
# [63]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [64]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [65]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [66]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [67]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [68]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [69]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [70]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [71]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [72]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [73]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [74]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [75]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [76]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [77]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [78]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [79]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [80]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [81]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [82]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [83]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [84]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [85]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [86]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [87]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [88]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [89]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [90]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [91]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [92]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [93]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [94]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [95]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 2 pruned nodes, max_depth=0
# [96]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [97]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [98]#011train-error:0.027523
# [14:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 4 pruned nodes, max_depth=0
# [99]#011train-error:0.027523
#
# 2022-04-23 14:09:06 Uploading - Uploading generated training model
# 2022-04-23 14:09:06 Completed - Training job completed
# Training seconds: 122
# Billable seconds: 122

# %%
# deploy the fitted model for prediction
xgb_predictor = xgb.deploy(initial_instance_count=1,instance_type='ml.m4.xlarge')
# Out:
# -------!

# %%
#Serializer 
from sagemaker.serializers import CSVSerializer

test_data_array = test_data.drop(['label'], axis=1).values #load the data into an array
xgb_predictor.serializer = CSVSerializer() # set the serializer type
predictions = xgb_predictor.predict(test_data_array).decode('utf-8') # predict!
predictions_array = np.fromstring(predictions[1:], sep=',') # and turn the prediction into an array
print(predictions_array.shape)
# Out:
# (188,)

# %%
#print the out come of our prediction
cm = pd.crosstab(index=test_data['label'], columns=np.round(predictions_array), rownames=['Observed'], colnames=['Predicted'])
tn = cm.iloc[0,0]; fn = cm.iloc[1,0]; tp = cm.iloc[1,1]; fp = cm.iloc[0,1]; p = (tp+tn)/(tp+tn+fp+fn)*100
print("\n{0:<20}{1:<4.1f}%\n".format("Overall Classification Rate: ", p))
print("{0:<15}{1:<15}{2:>8}".format("Predicted", "Less than 50%", "More than 50%"))
print("Observed")
print("{0:<15}{1:<2.0f}% ({2:<}){3:>6.0f}% ({4:<})".format("Less than 50%", tn/(tn+fn)*100,tn, fp/(tp+fp)*100, fp))
print("{0:<16}{1:<1.0f}% ({2:<}){3:>7.0f}% ({4:<}) \n".format("More than 50%", fn/(tn+fn)*100,fn, tp/(tp+fp)*100, tp))
# Out:
# Overall Classification Rate: 93.1%
#
# Predicted      Less than 50%  More than 50%
# Observed
# Less than 50%  93% (52)     7% (9)
# More than 50%   7% (4)     93% (123)

# %%
# all the code below are used for testing only 
test_data
# Out:
#      Industry Electricity  Industry Gas   Industry 'Other Fuels'  \
# 429             21.471378      28.171075               48.760413
# 237             43.524392      18.127447               39.148399
# 384             30.576951      18.814030               58.443575
# 366             50.480688     100.082530               13.109398
# 378             12.167436       4.994726               18.269672
# ..                    ...            ...                     ...
# 70              47.666017      54.049591               37.599949
# 132            105.011511     115.378414              145.563009
# 289             27.238769       9.761711               31.429824
# 109             67.413388     207.137841               50.903814
# 480            119.621481     112.958447               93.009119
#
#      Large Industrial Installations  Agriculture  Industry Total   2019 year  \
# 429                       13.089610    14.229823      125.722299     7.49466
# 237                        0.016560     0.596807      101.413605   152.75500
# 384                      107.993055    14.428038      230.255650  3196.71800
# 366                        1.134588     0.071980      164.879184    51.29100
# 378                        1.660167     9.457461       46.549461   200.39100
# ..                              ...          ...             ...         ...
# 70                        49.002407     1.204505      189.522469    17.74600
# 132                      524.963206    70.290386      961.206526    58.42880
# 289                        0.073522     6.951697       75.455523    11.13000
# 109                      178.246660     1.388202      505.089905    74.00000
# 480                      574.492574    16.256482      916.338103    55.80000
#
#      label
# 429      1
# 237      0
# 384      0
# 366      1
# 378      0
# ..     ...
# 70       1
# 132      1
# 289      1
# 109      1
# 480      1
#
# [188 rows x 8 columns]

# %%
js = test_data.iloc[0].to_json(orient = 'columns')
js
# Out:
# '{"Industry Electricity":21.4713780854,"Industry Gas ":28.1710746292,"Industry \'Other Fuels\'":48.760412829,"Large Industrial Installations":13.0896102274,"Agriculture":14.2298228162,"Industry Total":125.7222985872,"2019 year":7.49466,"label":1.0}'

# %%
xgb_predictor.endpoint
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 'xgboost-2022-04-23-14-09-27-392'

# %%
xgb_predictor.predict([21,28,48,13,14,125,7])
# Out:
# b'0.9814813137054443'

# %%
import io
def np2csv(arr):
    csv = io.BytesIO()

    np.savetxt(csv, arr, delimiter=",", fmt="%g")
    

    return csv.getvalue().decode().rstrip()

# %%
runtime = boto3.client("runtime.sagemaker")

# get the payload

payload = np2csv([[21,28,48,13,14,125,7]])
# invoke the endpoint to get the response

response = runtime.invoke_endpoint(

EndpointName='xgboost-2022-04-23-14-09-27-392', Body=payload, ContentType="text/csv")

# %%
result = json.loads(response["Body"].read().decode())

# %%
result
# Out:
# 0.9814813137054443

# %%
test= { "data": [[21,28,48,13,14,125,7]]}

# %%
data = json.loads(json.dumps(test))
payload = data["data"]
print(payload)
payload
# Out:
# [[21, 28, 48, 13, 14, 125, 7]]
# [[21, 28, 48, 13, 14, 125, 7]]

# %%
print(payload)
# Out:
# 21,28,48,13,14,125,7
